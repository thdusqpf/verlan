# %% [markdown]
# <a href="https://colab.research.google.com/github/thdusqpf/verlan/blob/main/Machine_Translation_(Verlan_to_French)_RNN_LSTM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## What is Machine Translation?
# Machine translation (MT) refers to fully automated software that can translate source content into target languages. Humans may use MT to help them render text and speech into another language, or the MT software may operate without human intervention.
#
#
# MT tools are often used to translate vast amounts of information involving millions of words that could not possibly be translated the traditional way. The quality of MT output can vary considerably; MT systems require “training” in the desired domain and language pair to increase quality.
#
# Translation companies use MT to augment productivity of their translators, cut costs, and provide post-editing services to clients. MT use by language service providers is growing quickly.
#
# Source: https://www.gala-global.org/what-machine-translation

# %% [markdown]
# This notebook is an implementation of the article : https://blog.keras.io/a-ten-minute-introduction-to-sequence-to-sequence-learning-in-keras.html

# %% [markdown]
# ## Let's start the process of building a model which translates English to French

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 5GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All"
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input,LSTM,Dense

batch_size=64
epochs=100
latent_dim=256
num_samples=10000

data_path='VerlanObjects.txt'

# %%
# Vectorize the data.
input_texts = []
target_texts = []
input_characters = set()
target_characters = set()
with open(data_path, 'r', encoding='utf-8') as f:
    lines = f.read().split('\n')
for line in lines[: min(num_samples, len(lines) - 1)]:
    target_text, input_text= line.split('\t')
    # We use "tab" as the "start sequence" character
    # for the targets, and "\n" as "end sequence" character.
    target_text = '\t' + target_text + '\n'
    input_texts.append(input_text)
    target_texts.append(target_text)
    for char in input_text:
        if char not in input_characters:
            input_characters.add(char)
    for char in target_text:
        if char not in target_characters:
            target_characters.add(char)

# %%
input_characters=sorted(list(input_characters))
target_characters=sorted(list(target_characters))

num_encoder_tokens=len(input_characters)
num_decoder_tokens=len(target_characters)

max_encoder_seq_length=max([len(txt) for txt in input_texts])
max_decoder_seq_length=max([len(txt) for txt in target_texts])

# %%
print('Number of samples:', len(input_texts))
print('Number of unique input tokens:', num_encoder_tokens)
print('Number of unique output tokens:', num_decoder_tokens)
print('Max sequence length for inputs:', max_encoder_seq_length)
print('Max sequence length for outputs:', max_decoder_seq_length)
# Out:
# Number of samples: 356
# Number of unique input tokens: 53
# Number of unique output tokens: 50
# Max sequence length for inputs: 14
# Max sequence length for outputs: 21

# %%
input_token_index=dict(
    [(char,i) for i, char in enumerate(input_characters)])
target_token_index=dict(
[(char,i) for i, char in enumerate(target_characters)])

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

encoder_input_data = np.zeros(
    (len(input_texts), max_encoder_seq_length, num_encoder_tokens),
    dtype='float32')
decoder_input_data = np.zeros(
    (len(input_texts), max_decoder_seq_length, num_decoder_tokens),
    dtype='float32')
decoder_target_data = np.zeros(
    (len(input_texts), max_decoder_seq_length, num_decoder_tokens),
    dtype='float32')

# %%
for i, (input_text, target_text) in enumerate(zip(input_texts, target_texts)):
    for t, char in enumerate(input_text):
        encoder_input_data[i, t, input_token_index[char]] = 1.
    encoder_input_data[i, t + 1:, input_token_index[' ']] = 1.
    for t, char in enumerate(target_text):
        # decoder_target_data is ahead of decoder_input_data by one timestep
        decoder_input_data[i, t, target_token_index[char]] = 1.
        if t > 0:
            # decoder_target_data will be ahead by one timestep
            # and will not include the start character.
            decoder_target_data[i, t - 1, target_token_index[char]] = 1.
    decoder_input_data[i, t + 1:, target_token_index[' ']] = 1.
    decoder_target_data[i, t:, target_token_index[' ']] = 1.

# %% [markdown]
# ## Defining the encoder and decoder

# %%
# Define an input sequence and process it.
encoder_inputs = Input(shape=(None, num_encoder_tokens))
encoder = LSTM(latent_dim, return_state=True)
encoder_outputs, state_h, state_c = encoder(encoder_inputs)
# We discard `encoder_outputs` and only keep the states.
encoder_states = [state_h, state_c]

# Set up the decoder, using `encoder_states` as initial state.
decoder_inputs = Input(shape=(None, num_decoder_tokens))
# We set up our decoder to return full output sequences,
# and to return internal states as well. We don't use the
# return states in the training model, but we will use them in inference.
decoder_lstm = LSTM(latent_dim, return_sequences=True, return_state=True)
decoder_outputs, _, _ = decoder_lstm(decoder_inputs,
                                     initial_state=encoder_states)
decoder_dense = Dense(num_decoder_tokens, activation='softmax')
decoder_outputs = decoder_dense(decoder_outputs)

# %%
# Define the model that will turn
# `encoder_input_data` & `decoder_input_data` into `decoder_target_data`
model = Model([encoder_inputs, decoder_inputs], decoder_outputs)

# Run training
model.compile(optimizer='rmsprop', loss='categorical_crossentropy',
              metrics=['accuracy'])
model.fit([encoder_input_data, decoder_input_data], decoder_target_data,
          batch_size=batch_size,
          epochs=epochs,
          validation_split=0.2)
# Out:
# Epoch 1/100
# 5/5 [==============================] - 6s 559ms/step - loss: 3.2337 - accuracy: 0.5287 - val_loss: 1.4050 - val_accuracy: 0.6713
# Epoch 2/100
# 5/5 [==============================] - 1s 210ms/step - loss: 1.3367 - accuracy: 0.6787 - val_loss: 1.3197 - val_accuracy: 0.6713
# Epoch 3/100
# 5/5 [==============================] - 1s 258ms/step - loss: 1.2661 - accuracy: 0.6789 - val_loss: 1.2195 - val_accuracy: 0.6713
# Epoch 4/100
# 5/5 [==============================] - 2s 315ms/step - loss: 1.1706 - accuracy: 0.6841 - val_loss: 1.2127 - val_accuracy: 0.6772
# Epoch 5/100
# 5/5 [==============================] - 1s 253ms/step - loss: 1.1997 - accuracy: 0.6965 - val_loss: 1.1503 - val_accuracy: 0.6892
# Epoch 6/100
# 5/5 [==============================] - 1s 184ms/step - loss: 1.1177 - accuracy: 0.6980 - val_loss: 1.1122 - val_accuracy: 0.6872
# Epoch 7/100
# 5/5 [==============================] - 1s 209ms/step - loss: 1.1255 - accuracy: 0.7009 - val_loss: 1.0988 - val_accuracy: 0.6878
# Epoch 8/100
# 5/5 [==============================] - 1s 206ms/step - loss: 1.0717 - accuracy: 0.7077 - val_loss: 1.0820 - val_accuracy: 0.6898
# Epoch 9/100
# 5/5 [==============================] - 1s 188ms/step - loss: 1.0635 - accuracy: 0.7114 - val_loss: 1.0941 - val_accuracy: 0.7004
# Epoch 10/100
# 5/5 [==============================] - 1s 191ms/step - loss: 1.0873 - accuracy: 0.7019 - val_loss: 1.0960 - val_accuracy: 0.6865
# Epoch 11/100
# 5/5 [==============================] - 1s 209ms/step - loss: 1.0401 - accuracy: 0.7084 - val_loss: 1.0533 - val_accuracy: 0.7083
# Epoch 12/100
# 5/5 [==============================] - 1s 206ms/step - loss: 1.0616 - accuracy: 0.7064 - val_loss: 1.1088 - val_accuracy: 0.6892
# Epoch 13/100
# 5/5 [==============================] - 1s 196ms/step - loss: 1.0298 - accuracy: 0.7118 - val_loss: 1.0539 - val_accuracy: 0.6911
# Epoch 14/100
# 5/5 [==============================] - 1s 190ms/step - loss: 1.0875 - accuracy: 0.7036 - val_loss: 1.0443 - val_accuracy: 0.7123
# Epoch 15/100
# 5/5 [==============================] - 1s 281ms/step - loss: 1.0191 - accuracy: 0.7218 - val_loss: 1.0391 - val_accuracy: 0.7110
# Epoch 16/100
# 5/5 [==============================] - 2s 379ms/step - loss: 1.0223 - accuracy: 0.7153 - val_loss: 1.0633 - val_accuracy: 0.6951
# Epoch 17/100
# 5/5 [==============================] - 1s 227ms/step - loss: 1.0439 - accuracy: 0.7124 - val_loss: 1.0283 - val_accuracy: 0.7176
# Epoch 18/100
# 5/5 [==============================] - 1s 201ms/step - loss: 1.0378 - accuracy: 0.7123 - val_loss: 1.0805 - val_accuracy: 0.6944
# Epoch 19/100
# 5/5 [==============================] - 1s 208ms/step - loss: 1.0205 - accuracy: 0.7198 - val_loss: 1.0208 - val_accuracy: 0.7176
# Epoch 20/100
# 5/5 [==============================] - 1s 213ms/step - loss: 0.9945 - accuracy: 0.7275 - val_loss: 1.0685 - val_accuracy: 0.6964
# Epoch 21/100
# 5/5 [==============================] - 1s 193ms/step - loss: 1.0229 - accuracy: 0.7153 - val_loss: 1.0129 - val_accuracy: 0.7077
# Epoch 22/100
# 5/5 [==============================] - 1s 213ms/step - loss: 1.0043 - accuracy: 0.7230 - val_loss: 1.0142 - val_accuracy: 0.7209
# Epoch 23/100
# 5/5 [==============================] - 1s 199ms/step - loss: 0.9826 - accuracy: 0.7262 - val_loss: 1.0045 - val_accuracy: 0.7196
# Epoch 24/100
# 5/5 [==============================] - 1s 207ms/step - loss: 1.0150 - accuracy: 0.7186 - val_loss: 1.0206 - val_accuracy: 0.7037
# Epoch 25/100
# 5/5 [==============================] - 1s 211ms/step - loss: 0.9702 - accuracy: 0.7269 - val_loss: 0.9961 - val_accuracy: 0.7235
# Epoch 26/100
# 5/5 [==============================] - 1s 192ms/step - loss: 0.9730 - accuracy: 0.7299 - val_loss: 1.1004 - val_accuracy: 0.6951
# Epoch 27/100
# 5/5 [==============================] - 1s 285ms/step - loss: 1.0041 - accuracy: 0.7191 - val_loss: 0.9953 - val_accuracy: 0.7037
# Epoch 28/100
# 5/5 [==============================] - 2s 303ms/step - loss: 0.9653 - accuracy: 0.7289 - val_loss: 0.9838 - val_accuracy: 0.7222
# Epoch 29/100
# 5/5 [==============================] - 1s 219ms/step - loss: 0.9524 - accuracy: 0.7316 - val_loss: 1.0256 - val_accuracy: 0.6991
# Epoch 30/100
# 5/5 [==============================] - 1s 214ms/step - loss: 0.9738 - accuracy: 0.7242 - val_loss: 1.0181 - val_accuracy: 0.7282
# Epoch 31/100
# 5/5 [==============================] - 1s 195ms/step - loss: 0.9502 - accuracy: 0.7357 - val_loss: 0.9757 - val_accuracy: 0.7242
# Epoch 32/100
# 5/5 [==============================] - 1s 192ms/step - loss: 0.9276 - accuracy: 0.7383 - val_loss: 0.9878 - val_accuracy: 0.7321
# Epoch 33/100
# 5/5 [==============================] - 1s 213ms/step - loss: 0.9860 - accuracy: 0.7282 - val_loss: 0.9746 - val_accuracy: 0.7130
# Epoch 34/100
# 5/5 [==============================] - 1s 202ms/step - loss: 0.9259 - accuracy: 0.7391 - val_loss: 0.9599 - val_accuracy: 0.7209
# Epoch 35/100
# 5/5 [==============================] - 1s 194ms/step - loss: 0.9549 - accuracy: 0.7394 - val_loss: 0.9574 - val_accuracy: 0.7328
# Epoch 36/100
# 5/5 [==============================] - 1s 188ms/step - loss: 0.9092 - accuracy: 0.7485 - val_loss: 0.9618 - val_accuracy: 0.7163
# Epoch 37/100
# 5/5 [==============================] - 1s 188ms/step - loss: 0.9180 - accuracy: 0.7406 - val_loss: 1.0298 - val_accuracy: 0.7295
# Epoch 38/100
# 5/5 [==============================] - 1s 183ms/step - loss: 0.9506 - accuracy: 0.7376 - val_loss: 0.9607 - val_accuracy: 0.7202
# Epoch 39/100
# 5/5 [==============================] - 1s 263ms/step - loss: 0.9033 - accuracy: 0.7470 - val_loss: 1.0072 - val_accuracy: 0.7341
# Epoch 40/100
# 5/5 [==============================] - 2s 303ms/step - loss: 0.9324 - accuracy: 0.7408 - val_loss: 0.9447 - val_accuracy: 0.7282
# Epoch 41/100
# 5/5 [==============================] - 1s 231ms/step - loss: 0.8903 - accuracy: 0.7495 - val_loss: 0.9289 - val_accuracy: 0.7374
# Epoch 42/100
# 5/5 [==============================] - 1s 190ms/step - loss: 0.8865 - accuracy: 0.7503 - val_loss: 1.0404 - val_accuracy: 0.7030
# Epoch 43/100
# 5/5 [==============================] - 1s 202ms/step - loss: 0.9328 - accuracy: 0.7401 - val_loss: 0.9241 - val_accuracy: 0.7354
# Epoch 44/100
# 5/5 [==============================] - 1s 218ms/step - loss: 0.8798 - accuracy: 0.7554 - val_loss: 0.9305 - val_accuracy: 0.7421
# Epoch 45/100
# 5/5 [==============================] - 1s 229ms/step - loss: 0.8690 - accuracy: 0.7570 - val_loss: 0.9256 - val_accuracy: 0.7302
# Epoch 46/100
# 5/5 [==============================] - 1s 180ms/step - loss: 0.8733 - accuracy: 0.7495 - val_loss: 0.9336 - val_accuracy: 0.7407
# Epoch 47/100
# 5/5 [==============================] - 1s 197ms/step - loss: 0.9003 - accuracy: 0.7534 - val_loss: 0.9438 - val_accuracy: 0.7196
# Epoch 48/100
# 5/5 [==============================] - 1s 203ms/step - loss: 0.8583 - accuracy: 0.7555 - val_loss: 0.9007 - val_accuracy: 0.7493
# Epoch 49/100
# 5/5 [==============================] - 1s 211ms/step - loss: 0.8435 - accuracy: 0.7624 - val_loss: 0.9234 - val_accuracy: 0.7361
# Epoch 50/100
# 5/5 [==============================] - 1s 211ms/step - loss: 0.9263 - accuracy: 0.7428 - val_loss: 0.9050 - val_accuracy: 0.7414
# Epoch 51/100
# 5/5 [==============================] - 1s 293ms/step - loss: 0.8388 - accuracy: 0.7651 - val_loss: 0.8928 - val_accuracy: 0.7460
# Epoch 52/100
# 5/5 [==============================] - 2s 303ms/step - loss: 0.8310 - accuracy: 0.7668 - val_loss: 0.8964 - val_accuracy: 0.7513
# Epoch 53/100
# 5/5 [==============================] - 1s 199ms/step - loss: 0.8500 - accuracy: 0.7617 - val_loss: 0.8888 - val_accuracy: 0.7427
# Epoch 54/100
# 5/5 [==============================] - 1s 186ms/step - loss: 0.8412 - accuracy: 0.7634 - val_loss: 0.9832 - val_accuracy: 0.7480
# Epoch 55/100
# 5/5 [==============================] - 1s 218ms/step - loss: 0.8560 - accuracy: 0.7651 - val_loss: 0.8797 - val_accuracy: 0.7434
# Epoch 56/100
# 5/5 [==============================] - 1s 211ms/step - loss: 0.8134 - accuracy: 0.7720 - val_loss: 0.8785 - val_accuracy: 0.7540
# Epoch 57/100
# 5/5 [==============================] - 1s 208ms/step - loss: 0.8183 - accuracy: 0.7681 - val_loss: 0.9075 - val_accuracy: 0.7434
# Epoch 58/100
# 5/5 [==============================] - 1s 199ms/step - loss: 0.8491 - accuracy: 0.7629 - val_loss: 0.8938 - val_accuracy: 0.7526
# Epoch 59/100
# 5/5 [==============================] - 1s 210ms/step - loss: 0.8086 - accuracy: 0.7713 - val_loss: 0.8645 - val_accuracy: 0.7480
# Epoch 60/100
# 5/5 [==============================] - 1s 206ms/step - loss: 0.7974 - accuracy: 0.7735 - val_loss: 0.8824 - val_accuracy: 0.7454
# Epoch 61/100
# 5/5 [==============================] - 1s 191ms/step - loss: 0.8122 - accuracy: 0.7669 - val_loss: 0.8586 - val_accuracy: 0.7626
# Epoch 62/100
# 5/5 [==============================] - 1s 194ms/step - loss: 0.7942 - accuracy: 0.7758 - val_loss: 1.0425 - val_accuracy: 0.7229
# Epoch 63/100
# 5/5 [==============================] - 1s 297ms/step - loss: 0.8525 - accuracy: 0.7597 - val_loss: 0.8574 - val_accuracy: 0.7533
# Epoch 64/100
# 5/5 [==============================] - 2s 307ms/step - loss: 0.7849 - accuracy: 0.7775 - val_loss: 0.8468 - val_accuracy: 0.7593
# Epoch 65/100
# 5/5 [==============================] - 1s 203ms/step - loss: 0.7844 - accuracy: 0.7735 - val_loss: 0.8779 - val_accuracy: 0.7467
# Epoch 66/100
# 5/5 [==============================] - 1s 205ms/step - loss: 0.7790 - accuracy: 0.7798 - val_loss: 0.8555 - val_accuracy: 0.7480
# Epoch 67/100
# 5/5 [==============================] - 1s 201ms/step - loss: 0.7845 - accuracy: 0.7780 - val_loss: 0.8384 - val_accuracy: 0.7546
# Epoch 68/100
# 5/5 [==============================] - 1s 190ms/step - loss: 0.7652 - accuracy: 0.7819 - val_loss: 0.8587 - val_accuracy: 0.7533
# Epoch 69/100
# 5/5 [==============================] - 1s 189ms/step - loss: 0.7818 - accuracy: 0.7767 - val_loss: 0.8622 - val_accuracy: 0.7500
# Epoch 70/100
# 5/5 [==============================] - 1s 205ms/step - loss: 0.7878 - accuracy: 0.7755 - val_loss: 0.8377 - val_accuracy: 0.7639
# Epoch 71/100
# 5/5 [==============================] - 1s 182ms/step - loss: 0.7629 - accuracy: 0.7795 - val_loss: 0.8546 - val_accuracy: 0.7573
# Epoch 72/100
# 5/5 [==============================] - 1s 187ms/step - loss: 0.7543 - accuracy: 0.7788 - val_loss: 0.8433 - val_accuracy: 0.7612
# Epoch 73/100
# 5/5 [==============================] - 1s 204ms/step - loss: 0.7514 - accuracy: 0.7839 - val_loss: 0.8436 - val_accuracy: 0.7586
# Epoch 74/100
# 5/5 [==============================] - 1s 201ms/step - loss: 0.7587 - accuracy: 0.7807 - val_loss: 0.8218 - val_accuracy: 0.7679
# Epoch 75/100
# 5/5 [==============================] - 2s 332ms/step - loss: 0.7363 - accuracy: 0.7844 - val_loss: 0.8533 - val_accuracy: 0.7665
# Epoch 76/100
# 5/5 [==============================] - 2s 353ms/step - loss: 0.7628 - accuracy: 0.7814 - val_loss: 0.8365 - val_accuracy: 0.7513
# Epoch 77/100
# 5/5 [==============================] - 2s 348ms/step - loss: 0.7400 - accuracy: 0.7829 - val_loss: 0.8116 - val_accuracy: 0.7646
# Epoch 78/100
# 5/5 [==============================] - 1s 216ms/step - loss: 0.7252 - accuracy: 0.7857 - val_loss: 0.8252 - val_accuracy: 0.7487
# Epoch 79/100
# 5/5 [==============================] - 1s 186ms/step - loss: 0.7500 - accuracy: 0.7736 - val_loss: 0.8056 - val_accuracy: 0.7632
# Epoch 80/100
# 5/5 [==============================] - 1s 184ms/step - loss: 0.7225 - accuracy: 0.7891 - val_loss: 0.8173 - val_accuracy: 0.7619
# Epoch 81/100
# 5/5 [==============================] - 1s 187ms/step - loss: 0.7168 - accuracy: 0.7912 - val_loss: 0.8095 - val_accuracy: 0.7692
# Epoch 82/100
# 5/5 [==============================] - 1s 181ms/step - loss: 0.7273 - accuracy: 0.7889 - val_loss: 0.8010 - val_accuracy: 0.7672
# Epoch 83/100
# 5/5 [==============================] - 1s 207ms/step - loss: 0.7096 - accuracy: 0.7934 - val_loss: 0.8540 - val_accuracy: 0.7540
# Epoch 84/100
# 5/5 [==============================] - 1s 186ms/step - loss: 0.7397 - accuracy: 0.7800 - val_loss: 0.8014 - val_accuracy: 0.7619
# Epoch 85/100
# 5/5 [==============================] - 1s 205ms/step - loss: 0.7076 - accuracy: 0.7887 - val_loss: 0.8251 - val_accuracy: 0.7632
# Epoch 86/100
# 5/5 [==============================] - 1s 205ms/step - loss: 0.7024 - accuracy: 0.7919 - val_loss: 0.7950 - val_accuracy: 0.7619
# Epoch 87/100
# 5/5 [==============================] - 1s 206ms/step - loss: 0.7003 - accuracy: 0.7907 - val_loss: 0.8006 - val_accuracy: 0.7751
# Epoch 88/100
# 5/5 [==============================] - 1s 218ms/step - loss: 0.7018 - accuracy: 0.7904 - val_loss: 0.7934 - val_accuracy: 0.7731
# Epoch 89/100
# 5/5 [==============================] - 1s 291ms/step - loss: 0.6951 - accuracy: 0.7964 - val_loss: 0.7836 - val_accuracy: 0.7692
# Epoch 90/100
# 5/5 [==============================] - 1s 279ms/step - loss: 0.6915 - accuracy: 0.7914 - val_loss: 0.7834 - val_accuracy: 0.7685
# Epoch 91/100
# 5/5 [==============================] - 1s 198ms/step - loss: 0.6838 - accuracy: 0.7956 - val_loss: 0.7928 - val_accuracy: 0.7665
# Epoch 92/100
# 5/5 [==============================] - 1s 179ms/step - loss: 0.6807 - accuracy: 0.7929 - val_loss: 0.7743 - val_accuracy: 0.7705
# Epoch 93/100
# 5/5 [==============================] - 1s 190ms/step - loss: 0.6783 - accuracy: 0.7980 - val_loss: 0.7735 - val_accuracy: 0.7685
# Epoch 94/100
# 5/5 [==============================] - 1s 187ms/step - loss: 0.6785 - accuracy: 0.7951 - val_loss: 0.8039 - val_accuracy: 0.7679
# Epoch 95/100
# 5/5 [==============================] - 1s 188ms/step - loss: 0.6789 - accuracy: 0.7975 - val_loss: 0.7580 - val_accuracy: 0.7731
# Epoch 96/100
# 5/5 [==============================] - 1s 190ms/step - loss: 0.6619 - accuracy: 0.8020 - val_loss: 0.7619 - val_accuracy: 0.7791
# Epoch 97/100
# 5/5 [==============================] - 1s 186ms/step - loss: 0.6506 - accuracy: 0.8040 - val_loss: 0.7610 - val_accuracy: 0.7765
# Epoch 98/100
# 5/5 [==============================] - 1s 209ms/step - loss: 0.6615 - accuracy: 0.7973 - val_loss: 0.7783 - val_accuracy: 0.7725
# Epoch 99/100
# 5/5 [==============================] - 1s 206ms/step - loss: 0.6540 - accuracy: 0.8035 - val_loss: 0.7823 - val_accuracy: 0.7751
# Epoch 100/100
# 5/5 [==============================] - 1s 219ms/step - loss: 0.6574 - accuracy: 0.7988 - val_loss: 0.7687 - val_accuracy: 0.7738

# %%
model.save('french2verlan.h5')
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
# Define sampling models
encoder_model = Model(encoder_inputs, encoder_states)

decoder_state_input_h = Input(shape=(latent_dim,))
decoder_state_input_c = Input(shape=(latent_dim,))
decoder_states_inputs = [decoder_state_input_h, decoder_state_input_c]
decoder_outputs, state_h, state_c = decoder_lstm(
    decoder_inputs, initial_state=decoder_states_inputs)
decoder_states = [state_h, state_c]
decoder_outputs = decoder_dense(decoder_outputs)
decoder_model = Model(
    [decoder_inputs] + decoder_states_inputs,
    [decoder_outputs] + decoder_states)

# Reverse-lookup token index to decode sequences back to
# something readable.
reverse_input_char_index = dict(
    (i, char) for char, i in input_token_index.items())
reverse_target_char_index = dict(
    (i, char) for char, i in target_token_index.items())

# %%
def decode_sequence(input_seq):
    # Encode the input as state vectors.
    states_value = encoder_model.predict(input_seq)

    # Generate empty target sequence of length 1.
    target_seq = np.zeros((1, 1, num_decoder_tokens))
    # Populate the first character of target sequence with the start character.
    target_seq[0, 0, target_token_index['\t']] = 1.

    # Sampling loop for a batch of sequences
    # (to simplify, here we assume a batch of size 1).
    stop_condition = False
    decoded_sentence = ''
    while not stop_condition:
        output_tokens, h, c = decoder_model.predict(
            [target_seq] + states_value)

        # Sample a token
        sampled_token_index = np.argmax(output_tokens[0, -1, :])
        sampled_char = reverse_target_char_index[sampled_token_index]
        decoded_sentence += sampled_char

        # Exit condition: either hit max length
        # or find stop character.
        if (sampled_char == '\n' or
           len(decoded_sentence) > max_decoder_seq_length):
            stop_condition = True

        # Update the target sequence (of length 1).
        target_seq = np.zeros((1, 1, num_decoder_tokens))
        target_seq[0, 0, sampled_token_index] = 1.

        # Update states
        states_value = [h, c]

    return decoded_sentence

# %%
for seq_index in range(100):
    # Take one sequence (part of the training set)
    # for trying out decoding.
    input_seq = encoder_input_data[seq_index: seq_index + 1]
    decoded_sentence = decode_sequence(input_seq)
    print('-')
    print('Input sentence:', input_texts[seq_index])
    print('Decoded sentence:', decoded_sentence)
# Out:
# 1/1 [==============================] - 0s 439ms/step
# 1/1 [==============================] - 1s 723ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 49ms/step
# -
# Input sentence: Cainri
# Decoded sentence: Bacare
#
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# -
# Input sentence: Beur
# Decoded sentence: Pete
#
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# -
# Input sentence: Rebeu
# Decoded sentence: Pete
#
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 32ms/step
# -
# Input sentence: Reubeu
# Decoded sentence: Fete
#
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 29ms/step
# -
# Input sentence: genhar
# Decoded sentence: Bacane
#
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# -
# Input sentence: avoir reup
# Decoded sentence: Bouche
#
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 34ms/step
# -
# Input sentence: zebe
# Decoded sentence: mene
#
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 29ms/step
# -
# Input sentence: zeber
# Decoded sentence: mance
#
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 27ms/step
# -
# Input sentence: Lanceba
# Decoded sentence: Bacare
#
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 30ms/step
# -
# Input sentence: Deban
# Decoded sentence: maine
#
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 28ms/step
# -
# Input sentence: Beubard
# Decoded sentence: mouche
#
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# -
# Input sentence: retba
# Decoded sentence: poute
#
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 27ms/step
# -
# Input sentence: Sketba
# Decoded sentence: Bacare
#
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 41ms/step
# -
# Input sentence: Tarba
# Decoded sentence: pourete
#
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 59ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 45ms/step
# -
# Input sentence: Gossebo
# Decoded sentence: Bacarete
#
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 40ms/step
# -
# Input sentence: teube
# Decoded sentence: Pote
#
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 42ms/step
# -
# Input sentence: tebe
# Decoded sentence: Poute
#
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 31ms/step
# -
# Input sentence: Donbi
# Decoded sentence: pouche
#
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# -
# Input sentence: teub
# Decoded sentence: Pote
#
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 28ms/step
# -
# Input sentence: teubi
# Decoded sentence: Poue
#
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 29ms/step
# -
# Input sentence: zarbi
# Decoded sentence: Bacare
#
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 27ms/step
# -
# Input sentence: zarbe
# Decoded sentence: macare
#
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 28ms/step
# -
# Input sentence: keubla
# Decoded sentence: mache
#
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# -
# Input sentence: kebla
# Decoded sentence: macare
#
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 28ms/step
# -
# Input sentence: kebla
# Decoded sentence: macare
#
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 26ms/step
# -
# Input sentence: keubla
# Decoded sentence: mache
#
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 29ms/step
# -
# Input sentence: queblo
# Decoded sentence: mouche
#
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 46ms/step
# -
# Input sentence: beubon
# Decoded sentence: poure
#
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 47ms/step
# -
# Input sentence: bebon
# Decoded sentence: pourete
#
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 29ms/step
# -
# Input sentence: beubon
# Decoded sentence: poure
#
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 29ms/step
# -
# Input sentence: bebon
# Decoded sentence: pourete
#
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 36ms/step
# -
# Input sentence: Nombo
# Decoded sentence: Bomache
#
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 35ms/step
# -
# Input sentence: Jourbon
# Decoded sentence: Bouche
#
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 34ms/step
# -
# Input sentence: cheubou
# Decoded sentence: pouche
#
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 31ms/step
# -
# Input sentence: chebou cheub
# Decoded sentence: Bouche
#
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 32ms/step
# -
# Input sentence: Joibour
# Decoded sentence: Bouche
#
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 30ms/step
# -
# Input sentence: rebou
# Decoded sentence: poute
#
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 30ms/step
# -
# Input sentence: Teillebout
# Decoded sentence: pouche
#
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 26ms/step
# -
# Input sentence: Chebran
# Decoded sentence: Bacare
#
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 50ms/step
# -
# Input sentence: Sebu
# Decoded sentence: Fere
#
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 45ms/step
# -
# Input sentence: Nesbi
# Decoded sentence: Banche
#
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 35ms/step
# -
# Input sentence: Asse
# Decoded sentence: caie
#
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 34ms/step
# -
# Input sentence: Bleca
# Decoded sentence: pouche
#
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 28ms/step
# -
# Input sentence: Feca
# Decoded sentence: Fere
#
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 28ms/step
# -
# Input sentence: Bleric
# Decoded sentence: pouche
#
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 27ms/step
# -
# Input sentence: Meuca
# Decoded sentence: Coue
#
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 30ms/step
# -
# Input sentence: Poteca
# Decoded sentence: pourete
#
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 33ms/step
# -
# Input sentence: rotca
# Decoded sentence: pourete
#
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 31ms/step
# -
# Input sentence: rotteca
# Decoded sentence: pourote
#
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 31ms/step
# -
# Input sentence: rotka
# Decoded sentence: pourete
#
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 29ms/step
# -
# Input sentence: roteca
# Decoded sentence: pourete
#
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 30ms/step
# -
# Input sentence: Quesca
# Decoded sentence: Cane
#
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 41ms/step
# -
# Input sentence: teucha
# Decoded sentence: poute
#
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 47ms/step
# -
# Input sentence: teuch
# Decoded sentence: Pote
#
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 54ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 32ms/step
# -
# Input sentence: auch
# Decoded sentence: poute
#
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 30ms/step
# -
# Input sentence: reuche
# Decoded sentence: cate
#
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 30ms/step
# -
# Input sentence: reuch
# Decoded sentence: Pete
#
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 29ms/step
# -
# Input sentence: leuch
# Decoded sentence: Poue
#
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 28ms/step
# -
# Input sentence: veuch
# Decoded sentence: Sere
#
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 30ms/step
# -
# Input sentence: Veuche
# Decoded sentence: sere
#
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 31ms/step
# -
# Input sentence: Iench
# Decoded sentence: Caie
#
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 29ms/step
# -
# Input sentence: ienche
# Decoded sentence: mence
#
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 27ms/step
# -
# Input sentence: Yienche
# Decoded sentence: Cane
#
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 30ms/step
# -
# Input sentence: Yieche
# Decoded sentence: Caie
#
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 31ms/step
# -
# Input sentence: Noich
# Decoded sentence: Bacare
#
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 30ms/step
# -
# Input sentence: pecho
# Decoded sentence: pourete
#
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 44ms/step
# -
# Input sentence: garetci
# Decoded sentence: Bouche
#
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 42ms/step
# -
# Input sentence: abrege en garo
# Decoded sentence: Bouche
#
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 27ms/step
# -
# Input sentence: teci
# Decoded sentence: poute
#
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# -
# Input sentence: tess
# Decoded sentence: Pote
#
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# -
# Input sentence: secla
# Decoded sentence: mance
#
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 28ms/step
# -
# Input sentence: iencli
# Decoded sentence: mance
#
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 30ms/step
# -
# Input sentence: Charclo
# Decoded sentence: Boacare
#
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 34ms/step
# -
# Input sentence: Peuclot
# Decoded sentence: Coure
#
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 41ms/step
# -
# Input sentence: Asmeuk
# Decoded sentence: mache
#
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# -
# Input sentence: Comass
# Decoded sentence: Bouche
#
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# -
# Input sentence: kom ass
# Decoded sentence: Bouche
#
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 29ms/step
# -
# Input sentence: Pineco
# Decoded sentence: mache
#
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 29ms/step
# -
# Input sentence: Starco
# Decoded sentence: pouche
#
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 30ms/step
# -
# Input sentence: Yecou
# Decoded sentence: poute
#
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 45ms/step
# -
# Input sentence: Yoc
# Decoded sentence: poute
#
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 54ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 47ms/step
# -
# Input sentence: Zinc
# Decoded sentence: mance
#
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# -
# Input sentence: uc
# Decoded sentence: Fete
#
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 28ms/step
# -
# Input sentence: Leurdi
# Decoded sentence: Fere
#
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 29ms/step
# -
# Input sentence: foncede
# Decoded sentence: Bancen
#
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 32ms/step
# -
# Input sentence: fonsde
# Decoded sentence: ssene
#
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 29ms/step
# -
# Input sentence: gueudin
# Decoded sentence: Sere
#
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 30ms/step
# -
# Input sentence: guedin
# Decoded sentence: sene
#
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 34ms/step
# -
# Input sentence: Scredit
# Decoded sentence: Bacare
#
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 29ms/step
# -
# Input sentence: skeud
# Decoded sentence: sene
#
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 32ms/step
# -
# Input sentence: oide
# Decoded sentence: poute
#
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 28ms/step
# -
# Input sentence: Ouade
# Decoded sentence: Pete
#
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 28ms/step
# -
# Input sentence: Pedo
# Decoded sentence: Poue
#
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 28ms/step
# -
# Input sentence: Zedou
# Decoded sentence: Caie
#
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 28ms/step
# -
# Input sentence: Tecla
# Decoded sentence: poute
#
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 61ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 44ms/step
# -
# Input sentence: En deuspi
# Decoded sentence: ssense
#
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 47ms/step
# -
# Input sentence: venere
# Decoded sentence: sene
#
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 26ms/step
# -
# Input sentence: Verlan
# Decoded sentence: Bance
#
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# -
# Input sentence: Vesqui
# Decoded sentence: sene
#
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 29ms/step
# -
# Input sentence: Ainf
# Decoded sentence: caie
